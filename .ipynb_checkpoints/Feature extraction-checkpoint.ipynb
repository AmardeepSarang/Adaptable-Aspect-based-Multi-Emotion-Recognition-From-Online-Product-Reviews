# %%
#imports
import pandas as pd
import gzip
import json
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from collections import Counter
from nltk.corpus import opinion_lexicon
from nltk.corpus import subjectivity
from nltk.sentiment import SentimentAnalyzer
from nltk.sentiment.util import *
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.tokenize import sent_tokenize, word_tokenize

import math
import numpy as np
import spacy
import pickle
import random
nlp = spacy.load("en_core_web_sm")
# %matplotlib notebook

# %%
#constants 
TOP_N=10
PRODUCT_RECIPIENT_WORDS=['kid', 'son', 'grandson', 'daughter', 'grandaughter', 'nephew', 'niece', 'child', 'husband','wife']
PRODUCT_RECIPIENT="product_recipient"
PRODUCT_WORDS=['product','car','toy','car','item','thing']
PRODUCT="product"

# %% [markdown]
# # Load data

# %%
#import dataset
top_car_reviews= pd.read_pickle('dataset/top_car_reviews.pkl')
top_car_reviews
# Out:
#       overall  verified        asin      reviewerID  \
# 0         5.0      True  B00005LBZO  A2VY5QVWBX2YB3
# 1         5.0      True  B00005LBZO  A2VY5QVWBX2YB3
# 2         5.0     False  B00005LBZO  A136AQL8RG5WJJ
# 3         5.0     False  B00005LBZO  A136AQL8RG5WJJ
# 4         5.0     False  B00005LBZO  A2X3VRF0KE4C1Q
# ...       ...       ...         ...             ...
# 2045      1.0      True  B01CWSRW62  A2U221MZ3INE7U
# 2046      5.0      True  B01CWSRW62   APFZRYC2NR7XO
# 2047      5.0      True  B01CWSRW62  A16AHSSEEFOXU5
# 2048      1.0      True  B01CWSRW62  A291Y0FXKMLYFE
# 2049      5.0      True  B01CWSRW62  A1IDAUIGSYJMW3
#
#                                              reviewText  \
# 0     I remember playing with Kettcars when I was a ...
# 1     I remember playing with Kettcars when I was a ...
# 2     I am so very pleased with this product! I boug...
# 3     I am so very pleased with this product! I boug...
# 4     One of the best ride on toys for "little peopl...
# ...                                                 ...
# 2045  Stopped working after about 30-40 days, total ...
# 2046           It's impossible to get this thing stuck!
# 2047  My husband and our dog love it. It is very stu...
# 2048  Don't buy this.  Was fun for only a brief time...
# 2049                                        Fun FUN FUN
#
#                                                 summary  \
# 0                            A Great Toy for any Child!
# 1                            A Great Toy for any Child!
# 2                                   Kettler Karibo Cart
# 3                                   Kettler Karibo Cart
# 4                                A better pedal car....
# ...                                                 ...
# 2045               Good for 2 hours of play, then dies.
# 2046                                         Five Stars
# 2047  My husband and our dog love it. It is very stu...
# 2048  Was fun for only a brief time before it stoppe...
# 2049                                         Five Stars
#
#                                                   title  price
# 0                   Kettler Kettcar Kabrio Cart, Yellow
# 1                   Kettler Kettcar Kabrio Cart, Yellow
# 2                   Kettler Kettcar Kabrio Cart, Yellow
# 3                   Kettler Kettcar Kabrio Cart, Yellow
# 4                   Kettler Kettcar Kabrio Cart, Yellow
# ...                                                 ...    ...
# 2045  ZHMY Remote control Stunt Car Double-face work...  $5.24
# 2046  ZHMY Remote control Stunt Car Double-face work...  $5.24
# 2047  ZHMY Remote control Stunt Car Double-face work...  $5.24
# 2048  ZHMY Remote control Stunt Car Double-face work...  $5.24
# 2049  ZHMY Remote control Stunt Car Double-face work...  $5.24
#
# [2050 rows x 8 columns]

# %%
#gets all reviews for a given product as a list of strings
def get_reviews(df, asin):
    return df[df["asin"]==asin]["reviewText"].tolist()

# %%
review_list=get_reviews(top_car_reviews,'B00005LBZO')
review_list
# Out:
# ['I remember playing with Kettcars when I was a young person living in Germany. So when I later had children of my own I ordered them one too. They, and also all of the neighborhood kids, rode it for many years, and the only part that broke (after about 10 yrs of heavy \'ab\'use) was the plastic seat. After my sons were grown I then gave the Kettcar (with a home made wooden seat) to another family where it continued to serve their children for many more years. - I now have a young granddaugher and so I just purchased a new Kettcar for her too. She is now the 3rd generation in our family to ride around in Kettcars! The car arrived today and we all love it. In fact, my husband who is very mechanical and always quick to find flaws was very impressed too, as it is so sturdy and well built. It also shifts to \'neutral\' and has an easy to use brake. I would highly recommend this product. The model I bought is for younger children (my gr-dtr is only 3) but the company also makes larger ones for older kids. This toy is definitely built to last and can easily be passed on to the next generation too.&nbsp;<a data-hook="product-link-linked" class="a-link-normal" href="/Kettler-Kettcar-Kabrio-Cart/dp/B00005LBZO/ref=cm_cr_arp_d_rvw_txt?ie=UTF8">Kettler Kettcar Kabrio Cart</a>',
#  'I remember playing with Kettcars when I was a young person living in Germany. So when I later had children of my own I ordered them one too. They, and also all of the neighborhood kids, rode it for many years, and the only part that broke (after about 10 yrs of heavy \'ab\'use) was the plastic seat. After my sons were grown I then gave the Kettcar (with a home made wooden seat) to another family where it continued to serve their children for many more years. - I now have a young granddaugher and so I just purchased a new Kettcar for her too. She is now the 3rd generation in our family to ride around in Kettcars! The car arrived today and we all love it. In fact, my husband who is very mechanical and always quick to find flaws was very impressed too, as it is so sturdy and well built. It also shifts to \'neutral\' and has an easy to use brake. I would highly recommend this product. The model I bought is for younger children (my gr-dtr is only 3) but the company also makes larger ones for older kids. This toy is definitely built to last and can easily be passed on to the next generation too.&nbsp;<a data-hook="product-link-linked" class="a-link-normal" href="/Kettler-Kettcar-Kabrio-Cart/dp/B00005LBZO/ref=cm_cr_arp_d_rvw_txt?ie=UTF8">Kettler Kettcar Kabrio Cart</a>',
#  'I am so very pleased with this product! I bought two on faith that they would do the trick for our 4 and 6 year old grandsons. The construction is excellent and therefore, safe. The assembly is easy if you can hadle simple tools at all. They can navigate them well even on lawn and around the dirt areas of our yard. The best part is that they are kid powered and can only go as fast as they can peddle(on the flat). They get their exercise and can learn the skills of turning both forward and backward. Thank you for offering them.\nKitty',
#  'I am so very pleased with this product! I bought two on faith that they would do the trick for our 4 and 6 year old grandsons. The construction is excellent and therefore, safe. The assembly is easy if you can hadle simple tools at all. They can navigate them well even on lawn and around the dirt areas of our yard. The best part is that they are kid powered and can only go as fast as they can peddle(on the flat). They get their exercise and can learn the skills of turning both forward and backward. Thank you for offering them.\nKitty',
#  'One of the best ride on toys for "little people"...I purchased one for my grandson and he and my grandaughter want to ride it all the time....one of the best purchases I ever made....',
#  'One of the best ride on toys for "little people"...I purchased one for my grandson and he and my grandaughter want to ride it all the time....one of the best purchases I ever made....',
#  'This is the ride my 3 1/2 year old son prefers to all other ride-on toys.  He has a bike, a motorized Jeep, a cozy coupe (ride in plastic car), a wagon, and a stradle on 4 wheel bus.  He needs to ride this car everyday and it is not even our toy.  The neighbor purchased this Kettcar in a yard sale.  Her son is too small to reach the petals and my son has taken this car over.\nHe rides faster in it than any other bike.  It is very safe and low to the ground.  I am not worried about it tipping over like I am with his bike.  He passes all the motorized toys in the neighborhood.  He LOVES it! And he gets some exercise!',
#  'This is the ride my 3 1/2 year old son prefers to all other ride-on toys.  He has a bike, a motorized Jeep, a cozy coupe (ride in plastic car), a wagon, and a stradle on 4 wheel bus.  He needs to ride this car everyday and it is not even our toy.  The neighbor purchased this Kettcar in a yard sale.  Her son is too small to reach the petals and my son has taken this car over.\nHe rides faster in it than any other bike.  It is very safe and low to the ground.  I am not worried about it tipping over like I am with his bike.  He passes all the motorized toys in the neighborhood.  He LOVES it! And he gets some exercise!',
#  "The Kabrio will arrive at your home mostly assembled. You only need to assemble the seat assembly and steering wheel assembly. Very easy and they include a wrench that will be needed. Car is very sturdy but was a bit smaller than I though it would be. My 7 year old son fits on it easily though (he's small for his age) Seat has adjustability range of about 8 inches and adjusts easily without removing bolts or pins. Car pedals easily and has a shifter so you can shift out of gear and the car free wheels. This is good for coming down hills. Be warned that if the speed gets to high that the steering of the car is very fast and abrupt and it is possible to tip it over. Wheels are hard plastic with a softer vinyl tread over them. Traction has not been a problem for us. We purchased this item when it was greatly reduced and because of this we feel it was a great value. I don't know how happy I would be if I had paid full price though. In summary we think it is a great ride-on and well built that the kids think is cool!!",
#  "The Kabrio will arrive at your home mostly assembled. You only need to assemble the seat assembly and steering wheel assembly. Very easy and they include a wrench that will be needed. Car is very sturdy but was a bit smaller than I though it would be. My 7 year old son fits on it easily though (he's small for his age) Seat has adjustability range of about 8 inches and adjusts easily without removing bolts or pins. Car pedals easily and has a shifter so you can shift out of gear and the car free wheels. This is good for coming down hills. Be warned that if the speed gets to high that the steering of the car is very fast and abrupt and it is possible to tip it over. Wheels are hard plastic with a softer vinyl tread over them. Traction has not been a problem for us. We purchased this item when it was greatly reduced and because of this we feel it was a great value. I don't know how happy I would be if I had paid full price though. In summary we think it is a great ride-on and well built that the kids think is cool!!",
#  'my mom bought this for the grandkids (ages 6 and under) as they are outgrowing some of the of the ride on toys she has.  this purchase was with the hope that they could use it for years to come.  having said that, i didn\'t expect my 2 1/2 year old to fit perfectly well on it.  he is a great little "bike rider", so since this product is a bike in the form of a go-kart, he mastered it right away.  i would definitely recommend this product, but i\'m unsure that it will last us many year with the kids still being able to fit on it like we hoped.',
#  'my mom bought this for the grandkids (ages 6 and under) as they are outgrowing some of the of the ride on toys she has.  this purchase was with the hope that they could use it for years to come.  having said that, i didn\'t expect my 2 1/2 year old to fit perfectly well on it.  he is a great little "bike rider", so since this product is a bike in the form of a go-kart, he mastered it right away.  i would definitely recommend this product, but i\'m unsure that it will last us many year with the kids still being able to fit on it like we hoped.',
#  "Because of snow conditions it's been difficult to use the car. Perhaps a future option would be 4 wheel drive. I tried chains but they interfered with the operation of the brakes. Only option is to wait for better conditions.",
#  "Because of snow conditions it's been difficult to use the car. Perhaps a future option would be 4 wheel drive. I tried chains but they interfered with the operation of the brakes. Only option is to wait for better conditions.",
#  "We've had this for a long time and our son love it. Everyone who comes over want to get on it. He is 7 now and still plays on it. I totally recommend it.",
#  "We've had this for a long time and our son love it. Everyone who comes over want to get on it. He is 7 now and still plays on it. I totally recommend it.",
#  'Easy to assembly, took about 30 minutes with both kids screaming, "Me first!" The whole time and lots of crying. Buy more than one if your child has siblings. After a few adjustments it is working great. I also got a used one from our neighbor and it needed the same adjustments as our new one. The seat holding levers like to fall down and release, I waked it with a hammer to tighten the rivets on both and know it holds over bumps and all. The chain was too loose, you can adjust the tension up by the pedals. Great exercise',
#  'Easy to assembly, took about 30 minutes with both kids screaming, "Me first!" The whole time and lots of crying. Buy more than one if your child has siblings. After a few adjustments it is working great. I also got a used one from our neighbor and it needed the same adjustments as our new one. The seat holding levers like to fall down and release, I waked it with a hammer to tighten the rivets on both and know it holds over bumps and all. The chain was too loose, you can adjust the tension up by the pedals. Great exercise',
#  "it's awesome fun, built well, and light weight. My son likes to get it going and pull the brake to skid out. We have had a year of fun with it so far and it's still a favorite.",
#  "it's awesome fun, built well, and light weight. My son likes to get it going and pull the brake to skid out. We have had a year of fun with it so far and it's still a favorite.",
#  'We bought this for my daughter years ago, but my younger son uses it now. It has been outside in the rain, sun, snow, and you name it. It is still in good condition. It is great to see him get on it now and get the heart rate up and not even know it. :) Love the Kettcar.',
#  'We bought this for my daughter years ago, but my younger son uses it now. It has been outside in the rain, sun, snow, and you name it. It is still in good condition. It is great to see him get on it now and get the heart rate up and not even know it. :) Love the Kettcar.',
#  "My five year old boy loves this little cart.  Well made, I'm sure it will last him a long time!  Highly reccomend!",
#  "My five year old boy loves this little cart.  Well made, I'm sure it will last him a long time!  Highly reccomend!",
#  "We have had this Kettcar for 10 years now, and it's still going strong with just some screws replaced here and there. We live on a hilly street and have finally worn down the tires (about $70 for new ones), and we're giving it away to a neighbor whose kids are still little, despite much griping from my kids! My boys have outgrown it but even the 13-year-old still crams himself into it, riding with his knees practically up his nose. (I am not kidding about that.)\n\nThis go-cart is one hot commodity on our street, let me tell you. We often had 5-6 kids waiting to take their turn to ride it, with arguments periodically breaking out if someone took too long! Seriously, it's that much fun -- they literally get to drive the cart and feel like little race car drivers.\n\nHighly, highly recommend as a special gift your children and their friends will love for years and years!!!",
#  "We have had this Kettcar for 10 years now, and it's still going strong with just some screws replaced here and there. We live on a hilly street and have finally worn down the tires (about $70 for new ones), and we're giving it away to a neighbor whose kids are still little, despite much griping from my kids! My boys have outgrown it but even the 13-year-old still crams himself into it, riding with his knees practically up his nose. (I am not kidding about that.)\n\nThis go-cart is one hot commodity on our street, let me tell you. We often had 5-6 kids waiting to take their turn to ride it, with arguments periodically breaking out if someone took too long! Seriously, it's that much fun -- they literally get to drive the cart and feel like little race car drivers.\n\nHighly, highly recommend as a special gift your children and their friends will love for years and years!!!",
#  'I love this thing. I bought it for my son and he loves it. But be warned it is small. My son is 2 years and 5 months old and he can peddle it just fine on the smallest setting.',
#  'I love this thing. I bought it for my son and he loves it. But be warned it is small. My son is 2 years and 5 months old and he can peddle it just fine on the smallest setting.',
#  'I found it to be v. well built and safe in use for kids up to 5.  They still can use it after that age but I feel it gets too small and slow for them.\nIt is a solid item and weathers v. well as kids left it outside in the rain on many occasions.  Parts do not bend if the kid hits sth.  Happy with this item, give my kids another\nchoice for active play outside.  the chair adjusts to the height  and it is easy to do. I would rather buy this then any tricycle or battery operated car for\nkids.',
#  'I found it to be v. well built and safe in use for kids up to 5.  They still can use it after that age but I feel it gets too small and slow for them.\nIt is a solid item and weathers v. well as kids left it outside in the rain on many occasions.  Parts do not bend if the kid hits sth.  Happy with this item, give my kids another\nchoice for active play outside.  the chair adjusts to the height  and it is easy to do. I would rather buy this then any tricycle or battery operated car for\nkids.',
#  'Way. Two. Small.',
#  'Way. Two. Small.',
#  'Awesome!',
#  'Awesome!',
#  'Perfect car for our three year old. She loves it. The investment is worth it. She will use it for years.',
#  'Perfect car for our three year old. She loves it. The investment is worth it. She will use it for years.',
#  'Best pedal car ever!  We got this for our now 3 year old\'s 3rd birthday and she was able to use it from the time she got it!  She is average height I guess, right at 36 or 37". The car is very sturdy...it even held my 200+ lb father-in-law...  My daughter has become very good at steering it and even turning around, just a month or two after getting it. Highly recommended for those parents who refuse to give in to the sedentary lifestyle of electric toy cars!',
#  'Best pedal car ever!  We got this for our now 3 year old\'s 3rd birthday and she was able to use it from the time she got it!  She is average height I guess, right at 36 or 37". The car is very sturdy...it even held my 200+ lb father-in-law...  My daughter has become very good at steering it and even turning around, just a month or two after getting it. Highly recommended for those parents who refuse to give in to the sedentary lifestyle of electric toy cars!',
#  'Got this for my 4yr old birthday and he loves it.  He has a pedal bike, and balance bike, and a scooter but was having a hard time with pedals - he would get frustrated because using the pedals was so much slower.  This cart solved it in apx 20 minutes.  Now he is flying around and loving it. Seems to be made very well.  Very little assembly.  Clear instructions.  Tires are great - not air filled, but big and solid, and good traction in sand and smooth flooring.  We have a polished concrete floor and car works perfect on it - no slipping.  Over all the cart seems very well made, everyone here very very happy.',
#  'Got this for my 4yr old birthday and he loves it.  He has a pedal bike, and balance bike, and a scooter but was having a hard time with pedals - he would get frustrated because using the pedals was so much slower.  This cart solved it in apx 20 minutes.  Now he is flying around and loving it. Seems to be made very well.  Very little assembly.  Clear instructions.  Tires are great - not air filled, but big and solid, and good traction in sand and smooth flooring.  We have a polished concrete floor and car works perfect on it - no slipping.  Over all the cart seems very well made, everyone here very very happy.',
#  "Bought this for our son's 3rd birthday. He figured out how to use it in no time and just loves it!",
#  "Bought this for our son's 3rd birthday. He figured out how to use it in no time and just loves it!",
#  "Everyone loves this car. Kids come over to use it when we take it to playground or trail. Only thing is when the trail goes downhill my 5 yr old had a hard time learning how to stop. He wants to put his legs out and we practiced many times. Its also located not too far from the wheels so if the wheels are going around fast and he reaches to brake and puts his hand in the wrong spot it could potentially be a hazard. When he's flying down the hill and needs to brake this could be a problem..I've had to run with him and help him slow down... the main problem we've experience is it picks up speed really fast and he just doesn't brake..  riding on level or with only the slightest grades is fine and we love this car.",
#  "Everyone loves this car. Kids come over to use it when we take it to playground or trail. Only thing is when the trail goes downhill my 5 yr old had a hard time learning how to stop. He wants to put his legs out and we practiced many times. Its also located not too far from the wheels so if the wheels are going around fast and he reaches to brake and puts his hand in the wrong spot it could potentially be a hazard. When he's flying down the hill and needs to brake this could be a problem..I've had to run with him and help him slow down... the main problem we've experience is it picks up speed really fast and he just doesn't brake..  riding on level or with only the slightest grades is fine and we love this car.",
#  'This item is so well made.l My grandson used it as a race car, a go kart, and as a tow truck. He tied a strong piece of cord to it and attached the other end to his other small vehicle that was partially in a hole and was able to pull it out. GREAT TOY!!!',
#  'This item is so well made.l My grandson used it as a race car, a go kart, and as a tow truck. He tied a strong piece of cord to it and attached the other end to his other small vehicle that was partially in a hole and was able to pull it out. GREAT TOY!!!',
#  'This is great my son is actually wanting to go out and pedel the cart! Gets both of us outside and moving!',
#  'This is great my son is actually wanting to go out and pedel the cart! Gets both of us outside and moving!',
#  'This is by far was best toy on the market and still is today! I remember when I was like 3 years old getting mine and it was the best thing ever! I still have mine today and I am 18 years old and i tried riding it, and it worked like a champ! Still fantastic condition. Never getting rid of mine. Saving for kids when I get them but that will be a while. So I would highly recommend this item.',
#  'This is by far was best toy on the market and still is today! I remember when I was like 3 years old getting mine and it was the best thing ever! I still have mine today and I am 18 years old and i tried riding it, and it worked like a champ! Still fantastic condition. Never getting rid of mine. Saving for kids when I get them but that will be a while. So I would highly recommend this item.']

# %%
test_review=review_list[7]
test_review
# Out:
# 'This is the ride my 3 1/2 year old son prefers to all other ride-on toys.  He has a bike, a motorized Jeep, a cozy coupe (ride in plastic car), a wagon, and a stradle on 4 wheel bus.  He needs to ride this car everyday and it is not even our toy.  The neighbor purchased this Kettcar in a yard sale.  Her son is too small to reach the petals and my son has taken this car over.\nHe rides faster in it than any other bike.  It is very safe and low to the ground.  I am not worried about it tipping over like I am with his bike.  He passes all the motorized toys in the neighborhood.  He LOVES it! And he gets some exercise!'

# %% [markdown]
# # Noun extraction (simple)

# %%
def isNaN(num):
    try:
        num=float(num)
    except:
        return False 
    return math.isnan(num)
#takes in a review and returs all nouns in the review
def get_nouns(text):
    
    if isNaN(text):
        return []
    sentences = nltk.sent_tokenize(text) #tokenize sentences
    nouns = [] #empty to array to hold all nouns

    for sentence in sentences:
         for word,pos in nltk.pos_tag(nltk.word_tokenize(str(sentence))):
             if (pos == 'NN' or pos == 'NNP' or pos == 'NNS' or pos == 'NNPS'):
                 nouns.append(word)
    return nouns

noun_list=get_nouns(test_review)

# %%
noun_list
# Out:
# ['ride',
#  'year',
#  'son',
#  'prefers',
#  'toys',
#  'bike',
#  'Jeep',
#  'cozy',
#  'coupe',
#  'car',
#  'wagon',
#  'stradle',
#  'wheel',
#  'bus',
#  'car',
#  'everyday',
#  'toy',
#  'neighbor',
#  'Kettcar',
#  'sale',
#  'son',
#  'petals',
#  'son',
#  'car',
#  'bike',
#  'ground',
#  'bike',
#  'toys',
#  'neighborhood',
#  'exercise']

# %% [markdown]
# # Noun list processing and consolidation

# %%
#takes a list of words and lemmatize then all, returns list of lemmatize words
def lem_list(words):
    lemmatizer = WordNetLemmatizer()
    
    lem_list=[]
    
    for word in words:
        lem_list.append(lemmatizer.lemmatize(word))
    return lem_list
noun_list=lem_list(noun_list)
#noun_list

# %%
#get list of words in title of given product
def get_title_words(asin):
    title=top_car_reviews.loc[top_car_reviews["asin"]==asin,"title"].unique()[0]
    title=title.lower()
    #print(title)
    tokenizer = nltk.RegexpTokenizer(r"\w+")
    word_list = tokenizer.tokenize(title)
    
    return word_list
get_title_words("B00005LBZO")
# Out:
# ['kettler', 'kettcar', 'kabrio', 'cart', 'yellow']

# %%
#get all nouns from all reviews in list
def get_nouns_all_reviews(review_list, get_fuc=get_nouns):
    all_nouns=[]
    for review in review_list:
        noun_list=get_fuc(review)
        
        #add to main list
        all_nouns.extend(noun_list)
    
    return all_nouns
#get list
all_nouns=get_nouns_all_reviews(review_list)

#preform cleaning 
#lemmatize
all_nouns=lem_list(all_nouns)

#make all words lower cases
all_nouns = [each_string.lower() for each_string in all_nouns]

#remove stop words from list
all_nouns = [word for word in all_nouns if word not in stopwords.words('english')]


print(len(all_nouns))
all_nouns
# Out:
# 770
# ['kettcars',
#  'person',
#  'germany',
#  'child',
#  'neighborhood',
#  'kid',
#  'year',
#  'part',
#  'yr',
#  "'ab'use",
#  'seat',
#  'son',
#  'kettcar',
#  'home',
#  'seat',
#  'family',
#  'child',
#  'year',
#  'granddaugher',
#  'kettcar',
#  'generation',
#  'family',
#  'kettcars',
#  'car',
#  'today',
#  'fact',
#  'husband',
#  'flaw',
#  'brake',
#  'product',
#  'model',
#  'child',
#  'gr-dtr',
#  'company',
#  'one',
#  'kid',
#  'toy',
#  'generation',
#  'too.',
#  'nbsp',
#  'class=',
#  'href=',
#  '/kettler-kettcar-kabrio-cart/dp/b00005lbzo/ref=cm_cr_arp_d_rvw_txt',
#  'ie=utf8',
#  'kettler',
#  'kettcar',
#  'kabrio',
#  'cart',
#  '<',
#  '/a',
#  '>',
#  'kettcars',
#  'person',
#  'germany',
#  'child',
#  'neighborhood',
#  'kid',
#  'year',
#  'part',
#  'yr',
#  "'ab'use",
#  'seat',
#  'son',
#  'kettcar',
#  'home',
#  'seat',
#  'family',
#  'child',
#  'year',
#  'granddaugher',
#  'kettcar',
#  'generation',
#  'family',
#  'kettcars',
#  'car',
#  'today',
#  'fact',
#  'husband',
#  'flaw',
#  'brake',
#  'product',
#  'model',
#  'child',
#  'gr-dtr',
#  'company',
#  'one',
#  'kid',
#  'toy',
#  'generation',
#  'too.',
#  'nbsp',
#  'class=',
#  'href=',
#  '/kettler-kettcar-kabrio-cart/dp/b00005lbzo/ref=cm_cr_arp_d_rvw_txt',
#  'ie=utf8',
#  'kettler',
#  'kettcar',
#  'kabrio',
#  'cart',
#  '<',
#  '/a',
#  '>',
#  'product',
#  'faith',
#  'trick',
#  'year',
#  'grandson',
#  'construction',
#  'assembly',
#  'tool',
#  'lawn',
#  'dirt',
#  'area',
#  'yard',
#  'part',
#  'exercise',
#  'skill',
#  'forward',
#  'backward',
#  'thank',
#  'kitty',
#  'product',
#  'faith',
#  'trick',
#  'year',
#  'grandson',
#  'construction',
#  'assembly',
#  'tool',
#  'lawn',
#  'dirt',
#  'area',
#  'yard',
#  'part',
#  'exercise',
#  'skill',
#  'forward',
#  'backward',
#  'thank',
#  'kitty',
#  'ride',
#  'toy',
#  'people',
#  'grandson',
#  'grandaughter',
#  'time',
#  '....',
#  'purchase',
#  '....',
#  'ride',
#  'toy',
#  'people',
#  'grandson',
#  'grandaughter',
#  'time',
#  '....',
#  'purchase',
#  '....',
#  'ride',
#  'year',
#  'son',
#  'prefers',
#  'toy',
#  'bike',
#  'jeep',
#  'cozy',
#  'coupe',
#  'car',
#  'wagon',
#  'stradle',
#  'wheel',
#  'bus',
#  'car',
#  'everyday',
#  'toy',
#  'neighbor',
#  'kettcar',
#  'sale',
#  'son',
#  'petal',
#  'son',
#  'car',
#  'bike',
#  'ground',
#  'bike',
#  'toy',
#  'neighborhood',
#  'exercise',
#  'ride',
#  'year',
#  'son',
#  'prefers',
#  'toy',
#  'bike',
#  'jeep',
#  'cozy',
#  'coupe',
#  'car',
#  'wagon',
#  'stradle',
#  'wheel',
#  'bus',
#  'car',
#  'everyday',
#  'toy',
#  'neighbor',
#  'kettcar',
#  'sale',
#  'son',
#  'petal',
#  'son',
#  'car',
#  'bike',
#  'ground',
#  'bike',
#  'toy',
#  'neighborhood',
#  'exercise',
#  'kabrio',
#  'home',
#  'seat',
#  'assembly',
#  'wheel',
#  'wrench',
#  'car',
#  'year',
#  'son',
#  'age',
#  'seat',
#  'adjustability',
#  'range',
#  'inch',
#  'adjusts',
#  'bolt',
#  'pin',
#  'car',
#  'pedal',
#  'shifter',
#  'gear',
#  'car',
#  'wheel',
#  'hill',
#  'speed',
#  'steering',
#  'car',
#  'wheels',
#  'plastic',
#  'vinyl',
#  'tread',
#  'traction',
#  'problem',
#  'item',
#  'value',
#  'price',
#  'kid',
#  'kabrio',
#  'home',
#  'seat',
#  'assembly',
#  'wheel',
#  'wrench',
#  'car',
#  'year',
#  'son',
#  'age',
#  'seat',
#  'adjustability',
#  'range',
#  'inch',
#  'adjusts',
#  'bolt',
#  'pin',
#  'car',
#  'pedal',
#  'shifter',
#  'gear',
#  'car',
#  'wheel',
#  'hill',
#  'speed',
#  'steering',
#  'car',
#  'wheels',
#  'plastic',
#  'vinyl',
#  'tread',
#  'traction',
#  'problem',
#  'item',
#  'value',
#  'price',
#  'kid',
#  'mom',
#  'grandkids',
#  'age',
#  'ride',
#  'toy',
#  'purchase',
#  'hope',
#  'year',
#  'year',
#  'bike',
#  'rider',
#  'product',
#  'bike',
#  'form',
#  'go-kart',
#  'product',
#  'year',
#  'kid',
#  'mom',
#  'grandkids',
#  'age',
#  'ride',
#  'toy',
#  'purchase',
#  'hope',
#  'year',
#  'year',
#  'bike',
#  'rider',
#  'product',
#  'bike',
#  'form',
#  'go-kart',
#  'product',
#  'year',
#  'kid',
#  'condition',
#  'car',
#  'future',
#  'option',
#  'drive',
#  'chain',
#  'operation',
#  'brake',
#  'option',
#  'condition',
#  'condition',
#  'car',
#  'future',
#  'option',
#  'drive',
#  'chain',
#  'operation',
#  'brake',
#  'option',
#  'condition',
#  'time',
#  'son',
#  'everyone',
#  'time',
#  'son',
#  'everyone',
#  'easy',
#  'minute',
#  'kid',
#  'screaming',
#  'time',
#  'lot',
#  'buy',
#  'child',
#  'sibling',
#  'adjustment',
#  'neighbor',
#  'adjustment',
#  'seat',
#  'lever',
#  'release',
#  'hammer',
#  'rivet',
#  'bump',
#  'chain',
#  'tension',
#  'pedal',
#  'great',
#  'exercise',
#  'easy',
#  'minute',
#  'kid',
#  'screaming',
#  'time',
#  'lot',
#  'buy',
#  'child',
#  'sibling',
#  'adjustment',
#  'neighbor',
#  'adjustment',
#  'seat',
#  'lever',
#  'release',
#  'hammer',
#  'rivet',
#  'bump',
#  'chain',
#  'tension',
#  'pedal',
#  'great',
#  'exercise',
#  'fun',
#  'weight',
#  'son',
#  'brake',
#  'year',
#  'fun',
#  'favorite',
#  'fun',
#  'weight',
#  'son',
#  'brake',
#  'year',
#  'fun',
#  'favorite',
#  'daughter',
#  'year',
#  'son',
#  'rain',
#  'sun',
#  'snow',
#  'condition',
#  'heart',
#  'rate',
#  'kettcar',
#  'daughter',
#  'year',
#  'son',
#  'rain',
#  'sun',
#  'snow',
#  'condition',
#  'heart',
#  'rate',
#  'kettcar',
#  'year',
#  'boy',
#  'cart',
#  'time',
#  'highly',
#  'reccomend',
#  'year',
#  'boy',
#  'cart',
#  'time',
#  'highly',
#  'reccomend',
#  'kettcar',
#  'year',
#  'screw',
#  'street',
#  'tire',
#  'one',
#  'neighbor',
#  'kid',
#  'griping',
#  'kid',
#  'boy',
#  'knee',
#  'nose',
#  'go-cart',
#  'commodity',
#  'street',
#  'kid',
#  'turn',
#  'argument',
#  'someone',
#  'fun',
#  'cart',
#  'race',
#  'car',
#  'driver',
#  'highly',
#  'gift',
#  'child',
#  'friend',
#  'year',
#  'year',
#  'kettcar',
#  'year',
#  'screw',
#  'street',
#  'tire',
#  'one',
#  'neighbor',
#  'kid',
#  'griping',
#  'kid',
#  'boy',
#  'knee',
#  'nose',
#  'go-cart',
#  'commodity',
#  'street',
#  'kid',
#  'turn',
#  'argument',
#  'someone',
#  'fun',
#  'cart',
#  'race',
#  'car',
#  'driver',
#  'highly',
#  'gift',
#  'child',
#  'friend',
#  'year',
#  'year',
#  'thing',
#  'son',
#  'son',
#  'year',
#  'month',
#  'setting',
#  'thing',
#  'son',
#  'son',
#  'year',
#  'month',
#  'setting',
#  'use',
#  'kid',
#  'age',
#  'item',
#  'weather',
#  'kid',
#  'rain',
#  'occasion',
#  'parts',
#  'kid',
#  'sth',
#  'item',
#  'kid',
#  'choice',
#  'play',
#  'chair',
#  'height',
#  'tricycle',
#  'battery',
#  'car',
#  'kid',
#  'use',
#  'kid',
#  'age',
#  'item',
#  'weather',
#  'kid',
#  'rain',
#  'occasion',
#  'parts',
#  'kid',
#  'sth',
#  'item',
#  'kid',
#  'choice',
#  'play',
#  'chair',
#  'height',
#  'tricycle',
#  'battery',
#  'car',
#  'kid',
#  'way',
#  'small',
#  'way',
#  'small',
#  'awesome',
#  'awesome',
#  'car',
#  'year',
#  'investment',
#  'year',
#  'car',
#  'year',
#  'investment',
#  'year',
#  'best',
#  'pedal',
#  'car',
#  'year',
#  'birthday',
#  'time',
#  'car',
#  'father-in-law',
#  'daughter',
#  'month',
#  'highly',
#  'parent',
#  'lifestyle',
#  'toy',
#  'car',
#  'best',
#  'pedal',
#  'car',
#  'year',
#  'birthday',
#  'time',
#  'car',
#  'father-in-law',
#  'daughter',
#  'month',
#  'highly',
#  'parent',
#  'lifestyle',
#  'toy',
#  'car',
#  'got',
#  'birthday',
#  'pedal',
#  'bike',
#  'balance',
#  'bike',
#  'scooter',
#  'time',
#  'pedal',
#  'pedal',
#  'cart',
#  'minute',
#  'seems',
#  'assembly',
#  'instruction',
#  'tires',
#  'air',
#  'traction',
#  'sand',
#  'flooring',
#  'concrete',
#  'floor',
#  'car',
#  'work',
#  'slipping',
#  'cart',
#  'everyone',
#  'got',
#  'birthday',
#  'pedal',
#  'bike',
#  'balance',
#  'bike',
#  'scooter',
#  'time',
#  'pedal',
#  'pedal',
#  'cart',
#  'minute',
#  'seems',
#  'assembly',
#  'instruction',
#  'tires',
#  'air',
#  'traction',
#  'sand',
#  'flooring',
#  'concrete',
#  'floor',
#  'car',
#  'work',
#  'slipping',
#  'cart',
#  'everyone',
#  'bought',
#  'son',
#  'birthday',
#  'time',
#  'bought',
#  'son',
#  'birthday',
#  'time',
#  'everyone',
#  'car',
#  'kids',
#  'thing',
#  'trail',
#  'yr',
#  'time',
#  'leg',
#  'time',
#  'wheel',
#  'wheel',
#  'hand',
#  'spot',
#  'hazard',
#  'hill',
#  'problem',
#  '..',
#  'problem',
#  'experience',
#  'speed',
#  'level',
#  'grade',
#  'car',
#  'everyone',
#  'car',
#  'kids',
#  'thing',
#  'trail',
#  'yr',
#  'time',
#  'leg',
#  'time',
#  'wheel',
#  'wheel',
#  'hand',
#  'spot',
#  'hazard',
#  'hill',
#  'problem',
#  '..',
#  'problem',
#  'experience',
#  'speed',
#  'level',
#  'grade',
#  'car',
#  'item',
#  'grandson',
#  'race',
#  'car',
#  'kart',
#  'truck',
#  'piece',
#  'cord',
#  'end',
#  'vehicle',
#  'hole',
#  'toy',
#  'item',
#  'grandson',
#  'race',
#  'car',
#  'kart',
#  'truck',
#  'piece',
#  'cord',
#  'end',
#  'vehicle',
#  'hole',
#  'toy',
#  'son',
#  'cart',
#  'gets',
#  'son',
#  'cart',
#  'gets',
#  'toy',
#  'market',
#  'today',
#  'year',
#  'mine',
#  'thing',
#  'today',
#  'year',
#  'champ',
#  'condition',
#  'mine',
#  'kid',
#  'item',
#  'toy',
#  'market',
#  'today',
#  'year',
#  'mine',
#  'thing',
#  'today',
#  'year',
#  'champ',
#  'condition',
#  'mine',
#  'kid',
#  'item']

# %%
#count word ocerence
count_n=Counter(all_nouns).most_common(10)
print("{} : {}".format("blah",count_n))
# Out:
# blah : [('year', 40), ('car', 38), ('kid', 28), ('son', 24), ('toy', 18), ('time', 18), ('bike', 14), ('kettcar', 12), ('cart', 12), ('pedal', 12)]

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

#convert list to string and generat, vishulize noun list
unique_string=(" ").join(all_nouns)
wordcloud = WordCloud(width = 1000, height = 500).generate(unique_string)
plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
# Out:
# <div id='8ffeab9e-5125-422f-b6e3-03ecaafe487d'></div>
# (-0.5, 999.5, 499.5, -0.5)

# %%
#replaces simular words in list with a single word
def word_consolidation(word_list,consolidation_list,replace_word):
    new_list=[]
    
    for word in word_list:
        if word in consolidation_list:
            new_list.append(replace_word)
        else:
            new_list.append(word)
    return new_list

# %% [markdown]
# # Generate and output nouns to files

# %%
def output_nouns(f1,f2,asin, word_list, top_n=TOP_N):
    #print 10 most commen words
    c=Counter(word_list)
    count_n=c.most_common(top_n)
    pop_words=sorted(c, key = c.get, reverse = True)[:top_n]

    print("{} : {}".format(asin,count_n))
    
    #print words along with count
    print("{} : {}".format(asin,count_n), file = f1)
    
    #print top 10 words
    print("{},".format(asin), file = f2, end="")
    
    for word in pop_words:
        if word==pop_words[-1]:
            print("{}".format(word), file = f2, end="")
        else:
            print("{},".format(word), file = f2, end="")
        
    print("",file = f2)
    
    
    

    
#for all products get the top 10 nouns accross all reviews 
#get list of asins
asins=top_car_reviews["asin"].unique()
print(len(asins))
f_sufix="consolidated"
f_1_name="dataset/top_10_review_nouns_"+f_sufix+"_count.txt"
f_2_name="dataset/top_10_review_nouns_"+f_sufix+"_words.csv"

with open(f_1_name, "w+") as file_count, open(f_2_name, "w+") as file_words:
    #iterate over each product
    for asin in asins:
        #gets all reviews text for a given product as a list of strings
        review_list=get_reviews(top_car_reviews,asin)

        #get list of all nouns in all reviews
        #print(review_list)
        all_nouns=get_nouns_all_reviews(review_list)

        #preform cleaning on noun list 
        #lemmatize
        all_nouns=lem_list(all_nouns)

        #make all words lower cases
        all_nouns = [each_string.lower() for each_string in all_nouns]

        #remove stop words from list
        all_nouns = [word for word in all_nouns if word not in stopwords.words('english')]
        
        
        #remove words that are also in product title
        title_list=get_title_words(asin)
        all_nouns = [word for word in all_nouns if word not in title_list]
        
        
        
        #consolidate some words ie. words like 'kid', 'son', 'grandson', 'daughter', 'granddaughter', 'nephew', 'niece', 'child'
        #into single word "product_recipient"
        all_nouns=word_consolidation(all_nouns,PRODUCT_RECIPIENT_WORDS,PRODUCT_RECIPIENT)# recipient related words
        all_nouns=word_consolidation(all_nouns,PRODUCT_WORDS,PRODUCT)#product related words
        
        output_nouns(file_count,file_words,asin, all_nouns)
# Out:
# 30
# B00005LBZO : [('product', 80), ('product_recipient', 76), ('year', 40), ('time', 18), ('bike', 14), ('pedal', 12), ('seat', 10), ('wheel', 10), ('condition', 8), ('today', 6)]
# B000GPLT68 : [('product', 92), ('product_recipient', 54), ('wheel', 21), ('time', 17), ('quality', 14), ('race', 12), ('gift', 11), ('year', 11), ('piece', 11), ('christmas', 10)]
# B000Q9KPB4 : [('product', 54), ('model', 27), ('base', 14), ('quality', 13), ('wire', 11), ('box', 11), ('time', 10), ('corner', 8), ('top', 8), ('price', 8)]
# B002AKKO6S : [('product_recipient', 25), ('string', 25), ('product', 17), ('year', 15), ('quality', 14), ('sound', 13), ('price', 11), ('tune', 9), ('body', 7), ('instrument', 6)]
# B004KU83C8 : [('product', 38), ('product_recipient', 32), ('set', 17), ('quality', 9), ('thomas', 8), ('track', 8), ('year', 8), ('box', 6), ('engine', 6), ('fun', 6)]
# B004LH01ZW : [('product_recipient', 34), ('product', 29), ('battery', 19), ('wheel', 11), ('light', 8), ('day', 8), ('minute', 7), ('review', 7), ('fun', 7), ('color', 6)]
# B006RKH1I6 : [('product_recipient', 24), ('arm', 9), ('quality', 9), ('show', 8), ('transformer', 8), ('year', 7), ('product', 5), ('form', 3), ('hour', 3), ('set', 3)]
# B006RKBK0Q : [('product_recipient', 65), ('arm', 29), ('product', 28), ('quality', 24), ('show', 18), ('time', 17), ('year', 15), ('leg', 14), ('amazon', 12), ('transformer', 10)]
# B006RKFHBY : [('product_recipient', 39), ('product', 17), ('quality', 16), ('year', 14), ('arm', 11), ('show', 10), ('transformer', 10), ('korea', 6), ('leg', 5), ('day', 5)]
# B00AM9SZWO : [('product_recipient', 41), ('bong', 21), ('carry', 15), ('bongbong', 9), ('quality', 8), ('year', 8), ('product', 6), ('time', 6), ('lot', 5), ('picture', 5)]
# B00APTT9SU : [('product_recipient', 43), ('year', 11), ('rogi', 7), ('quality', 7), ('time', 5), ('size', 5), ('show', 4), ('door', 4), ('..', 4), ('hand', 4)]
# B00E849LS6 : [('product', 47), ('price', 12), ('product_recipient', 11), ('card', 10), ('collection', 9), ('wall', 7), ('plastic', 7), ('wheel', 7), ('star', 5), ('shipping', 5)]
# B00J97X2YG : [('window', 76), ('fan', 45), ('product', 43), ('vehicle', 21), ('rubber', 19), ('air', 19), ('unit', 15), ('sun', 14), ('day', 14), ('heat', 14)]
# B00JPTG45C : [('tool', 45), ('wheel', 30), ('derby', 15), ('product', 12), ('nail', 12), ('side', 12), ('year', 11), ('slot', 11), ('groove', 8), ('metal', 7)]
# B00KFBS5QA : [('product', 35), ('product_recipient', 22), ('communication', 4), ('quality', 4), ('seller', 4), ('price', 4), ('shipping', 4), ('day', 3), ('door', 3), ('wheel', 3)]
# B00KS6ADQW : [('product', 12), ('paint', 9), ('collection', 7), ('awesome', 6), ('detail', 5), ('job', 4), ('product_recipient', 4), ('box', 4), ('addition', 3), ('character', 2)]
# B00S4RM1XK : [('product_recipient', 60), ('cute', 26), ('color', 11), ('eye', 10), ('gift', 10), ('baby', 7), ('product', 7), ('blue', 6), ('collection', 6), ('super', 6)]
# B00TSV67XG : [('product', 10), ('time', 7), ('quality', 6), ('easy', 6), ('piece', 5), ('sturdy', 5), ('theme', 5), ('cute', 4), ('perfect', 4), ('stand', 4)]
# B00TWG57CY : [('product_recipient', 40), ('product', 38), ('bruder', 16), ('door', 12), ('quality', 11), ('year', 11), ('part', 9), ('vehicle', 8), ('christmas', 6), ('officer', 5)]
# B00V8LIPFW : [('product_recipient', 42), ('product', 40), ('bruder', 18), ('year', 13), ('door', 13), ('quality', 11), ('vehicle', 9), ('part', 9), ('price', 6), ('christmas', 6)]
# B0155MEP1C : [('product', 107), ('product_recipient', 39), ('price', 13), ('year', 11), ('fun', 11), ('time', 10), ('speed', 10), ('wheel', 9), ('rc', 7), ('box', 7)]
# B0155MVMFO : [('product', 94), ('product_recipient', 36), ('time', 18), ('rc', 17), ('year', 14), ('plastic', 13), ('controller', 12), ('speed', 11), ('fun', 10), ('wheel', 10)]
# B015SKSQUW : [('product', 18), ('product_recipient', 14), ('day', 11), ('costume', 11), ('skin', 9), ('year', 6), ('price', 6), ('time', 6), ('zombie', 6), ('job', 5)]
# B0162HF12Q : [('product', 40), ('product_recipient', 36), ('time', 22), ('day', 20), ('part', 18), ('battery', 16), ('wheel', 14), ('minute', 13), ('fun', 12), ('drive', 10)]
# B016YXI7YC : [('product', 29), ('battery', 24), ('time', 22), ('flight', 17), ('motor', 16), ('quad', 16), ('review', 13), ('size', 11), ('plastic', 10), ('money', 9)]
# B017AYXV9U : [('truck', 62), ('time', 46), ('product_recipient', 43), ('product', 38), ('part', 27), ('fun', 24), ('minute', 22), ('speed', 19), ('body', 18), ('day', 16)]
# B018VW1X4U : [('product_recipient', 29), ('product', 20), ('year', 9), ('quality', 8), ('door', 7), ('great', 7), ('seller', 7), ('price', 6), ('box', 6), ('gift', 6)]
# B01B55BPDY : [('product_recipient', 54), ('product', 49), ("k'nex", 31), ('piece', 24), ('year', 23), ('motor', 19), ('fun', 17), ('kit', 17), ('part', 16), ('race', 14)]
# B01CA4R218 : [('product_recipient', 23), ('product', 12), ('quality', 7), ('box', 6), ('door', 6), ('color', 4), ('engine', 4), ('piece', 4), ('year', 3), ('price', 3)]
# B01CWSRW62 : [('product_recipient', 17), ('battery', 15), ('product', 14), ('fun', 8), ('christmas', 5), ('minute', 5), ('day', 4), ('plug', 3), ('great', 3), ('wheel', 3)]

# %% [markdown]
# # Rule based extraction
# An advanced rule based approch to extract aspect words based on rules outlined in Venugopalana, Gupta's paper "An Unsupervised Hierarchical Rule Based Model for Aspect Term Extraction Augmented with Pruning Strategies"

# %%
#check of noun is in dobj relation with a verb
def find_dobj(text,noun, nlp=nlp):

    doc = nlp(text)
    for token in doc:
        #check if noun has dobj relation
        if token.dep_ == "dobj" and token.text==noun:
            return True

            #print(token.dep_,token.text,token.head.text)
            #print("{2}({3}-{6}, {0}-{5})".format(token.text, token.tag_, token.dep_, token.head.text, token.head.tag_, token.i+1, token.head.i+1))
    return False

#check of noun is in njubj relation with a verb
def find_nsubj(text,noun, nlp=nlp):

    doc = nlp(text)
    for token in doc:
        #check if noun has dobj relation
        if token.dep_ == "nsubj" and token.text==noun:
            return True

    return False

#find if the word hhas a relatiion with a copula verb
def find_copula(text,noun, nlp=nlp):

    doc = nlp(text)
    for token in doc:
        #check if noun has modifier relation
        #print("{2}({3}-{6}, {0}-{5})".format(token.text, token.tag_, token.dep_, token.head.text, token.head.tag_, token.i+1, token.head.i+1))        
        if token.dep_ == "cop" and token.head.text==noun:
            return True
    return False

#find the NER tag for a given word 

def find_ner_tag(text,word, nlp=nlp):
    doc = nlp(text)
    for token in doc:
        #check if noun has dobj relation
        #print( token.text, token.ent_type_)
        if token.text==word:
            return token.ent_type_
    return ""

#check that sentence contains atleast one opinion word 
def opin_word_in_sent(text,opin_lex=opinion_lexicon.words()):
    
    for word in nltk.word_tokenize(text):
        if word.lower() in opin_lex:
            return True
    return False

#an advanced rule based approch based on rules outlined in Venugopalana, Gupta's paper "An Unsupervised Hierarchical Rule Based Model for Aspect Term Extraction Augmented with Pruning Strategies"
def get_nouns_rule_based(text,opin_lex=opinion_lexicon.words()):
    
    if isNaN(text):
        return []
    sentences = nltk.sent_tokenize(text) #tokenize sentences
    aspect_words = [] #empty to array to hold all nouns

    
    for sentence in sentences:
        pos_tag_list=nltk.pos_tag(nltk.word_tokenize(str(sentence)))
        
        i=0
        for word,pos in pos_tag_list:
            pre_word=""
            pre_pos=""
            word=word.lower()
            if i>0:
                pre_word=pos_tag_list[i-1][0].lower()
                pre_pos=pos_tag_list[i-1][1]
            
            #R1: if word is a noun and preceded by an adjective which is not an opinion word then 
            #concatenate the word and its preceding word and append it to aspect[i]
            if (pos == 'NN' or pos == 'NNP' or pos == 'NNS' or pos == 'NNPS') and \
            (pre_pos == 'JJ' or pre_pos == 'JJR' or pre_pos == 'JJS') and pre_word not in opin_lex:
                aspect_words.append(pre_word+" "+word)
                    
            #R2: if word is a noun and preceded by another noun then concatenate the word and
            #its preceding word and append it to aspect[i]
            elif (pos == 'NN' or pos == 'NNP' or pos == 'NNS' or pos == 'NNPS') and \
            (pre_pos == 'NN' or pre_pos == 'NNP' or pre_pos == 'NNS' or pre_pos == "NNPS"):   
                aspect_words.append(pre_word+" "+word)
                
            #R3: if word is a noun and preceded by an adjective which is an opinion word then
            #append the word to aspect[i]
            elif (pos == 'NN' or pos == 'NNP' or pos == 'NNS' or pos == 'NNPS') and \
            (pre_pos == 'JJ' or pre_pos == 'JJR' or pre_pos == 'JJS') and pre_word in opin_lex:
                aspect_words.append(word)
            
            #R4: if word is a noun and is in a dobj relationship with a verb in the sentence then
            #append the word in aspect[i]
            #TODO see below functions
            elif (pos == 'NN' or pos == 'NNP' or pos == 'NNS' or pos == 'NNPS') and find_dobj(sentence, word):
                aspect_words.append(word)
                
            #R5: if word is a noun and is in a nsubj relationship with an adjective in the sentence
            #then append the word in aspect[i]
            elif (pos == 'NN' or pos == 'NNP' or pos == 'NNS' or pos == 'NNPS') and find_nsubj(sentence, word):
                aspect_words.append(word)
                
            #R6: if the sentence S[i] contains a SUBJECT VERB and if the word has any adverbial
            #or adjective modifier which is an opinion word append the word to aspect[i]
            #elif :
            
            #R7: if word is a noun and is in a modifier relationship with a copula verb in the
            #sentence then append the word to aspect[i]
            elif (pos == 'NN' or pos == 'NNP' or pos == 'NNS' or pos == 'NNPS') and find_copula(sentence,word):
                aspect_words.append(word)
                
            #R8: if word is a noun and if the previous word is not a preposition of place or a word
            #corresponding to an NER tag of {'TIME', 'ORDINAL', 'NUMBER', 'DATE','PERCENT’} 
            #and there is atleast one opinion word in the sentence , then append the word to aspect[i]
            elif (pos == 'NN' or pos == 'NNP' or pos == 'NNS' or pos == 'NNPS') and \
            find_ner_tag(sentence, pre_word) not in ['TIME','ORDINAL','DATE','QUANTITY','PERCENT'] and \
            opin_word_in_sent(sentence):
                aspect_words.append(word)
            i+=1   
            
    return aspect_words
    

aspect_list=get_nouns_rule_based(test_review)
print(len(aspect_list))
aspect_list
# Out:
# 26
# ['ride',
#  'old son',
#  'son prefers',
#  'ride-on toys',
#  'bike',
#  'motorized jeep',
#  'cozy',
#  'cozy coupe',
#  'plastic car',
#  'wagon',
#  'stradle',
#  'wheel',
#  'wheel bus',
#  'car',
#  'car everyday',
#  'neighbor',
#  'yard sale',
#  'son',
#  'petals',
#  'son',
#  'car',
#  'other bike',
#  'ground',
#  'bike',
#  'toys',
#  'exercise']

# %%
aspect_list=get_nouns(test_review)
print(len(aspect_list))
aspect_list
# Out:
# 30
# ['ride',
#  'year',
#  'son',
#  'prefers',
#  'toys',
#  'bike',
#  'Jeep',
#  'cozy',
#  'coupe',
#  'car',
#  'wagon',
#  'stradle',
#  'wheel',
#  'bus',
#  'car',
#  'everyday',
#  'toy',
#  'neighbor',
#  'Kettcar',
#  'sale',
#  'son',
#  'petals',
#  'son',
#  'car',
#  'bike',
#  'ground',
#  'bike',
#  'toys',
#  'neighborhood',
#  'exercise']

# %%
print(len(get_nouns_all_reviews(review_list, get_fuc=get_nouns)))
#uses the advanced rule base fuction
get_nouns_all_reviews(review_list, get_fuc=get_nouns_rule_based)
# Out:
# 262
# ['european plug',
#  'adapter ..',
#  'battery',
#  'wires',
#  'tryingto recharge',
#  'battery',
#  'wires',
#  'dollar-store quality',
#  'item',
#  'item today',
#  'great',
#  'great',
#  'little rc',
#  'rc car',
#  'shape',
#  'spins',
#  'straight line',
#  'rechargeable battery',
#  'battery pack',
#  'car',
#  'less batteries',
#  'other cars',
#  'same picture',
#  'con',
#  'controls',
#  'drive',
#  'drive wheel',
#  'actual turn',
#  'son',
#  'direction',
#  'car',
#  'foreign plug',
#  'order',
#  'adapter',
#  'u.s',
#  'house',
#  'surfaces',
#  'few stars',
#  'small defect',
#  'car',
#  'level cars',
#  'performance',
#  'toy',
#  'matter',
#  'remote',
#  'work',
#  'was',
#  'christmas',
#  'little boy',
#  'instructions',
#  'screw',
#  'screw driver',
#  'battery',
#  'work',
#  'frequency',
#  'red thinking',
#  'same time',
#  'controlled cars',
#  'car',
#  'money',
#  'short battery',
#  'battery life',
#  'minutes tops',
#  'n christmas',
#  'son',
#  'car',
#  'christmas',
#  'dud',
#  'lights',
#  'only thing',
#  'work',
#  'top',
#  'remote',
#  'power',
#  'power control',
#  'only way',
#  'batteries',
#  'defective',
#  'work',
#  'couple',
#  'uses',
#  'controller',
#  'fun',
#  'fun car',
#  'product',
#  'gave',
#  'grandson',
#  'birthday',
#  'wheel',
#  'day',
#  'cars',
#  'button',
#  'problem',
#  'value',
#  'cars',
#  'husband',
#  'truck',
#  'cars',
#  'was',
#  'was fun',
#  'kids',
#  'remote control',
#  'piece',
#  'junk',
#  'money',
#  '8th birthday',
#  'straight',
#  'box',
#  'work',
#  'full charge',
#  'car',
#  'stationary position',
#  'waste',
#  'excelent',
#  'grandson',
#  'day',
#  'year grandson',
#  'grandson loves',
#  'access battery',
#  'battery pack',
#  'tiny',
#  'son',
#  'birthday gift',
#  'last week',
#  'quit',
#  'battery',
#  'batteries',
#  'husband',
#  'grandson',
#  'blast',
#  'anything',
#  'dosnt',
#  'baseboards',
#  'blast',
#  'gears',
#  'wheels',
#  'abuse',
#  'toy',
#  'toy',
#  'thing',
#  'son',
#  'lots',
#  'fun',
#  'material',
#  'crash',
#  'wall',
#  'nothing',
#  'son',
#  'car',
#  'christmas',
#  'christmas morning',
#  'anything',
#  'needless',
#  'today',
#  'european plug',
#  'adapter',
#  'piece',
#  'crap',
#  'toy',
#  'fun',
#  'off/on switch',
#  'screwdriver',
#  'battery compartment',
#  'compartment cover',
#  'car',
#  'starts',
#  'money',
#  'products',
#  'great',
#  'information',
#  'rechargeable battery',
#  'remote control',
#  'aa',
#  'aa battery',
#  'product',
#  'product shares',
#  'same frequency',
#  'red car',
#  'green control',
#  'same place',
#  'small screw',
#  'time',
#  'charger',
#  'charger cord',
#  'pain',
#  'did',
#  'instructions',
#  'kid',
#  'christmas',
#  'grandsons race',
#  '30-40 days',
#  'total usage',
#  'stutters',
#  'stops',
#  'range',
#  'charge port',
#  'non-standard charging',
#  'charging cable',
#  'thing',
#  'thing stuck',
#  'husband',
#  'dog',
#  'things',
#  'only improvement',
#  'extra battery',
#  'life',
#  'was',
#  'was fun',
#  'brief time',
#  'changes battiers',
#  'stilk nothing',
#  'toy',
#  'son',
#  'heart',
#  'santa',
#  'work',
#  'week',
#  'santa',
#  'toys',
#  'fun',
#  'fun fun',
#  'fun fun']

# %%
#for all products get the top 10 nouns accross all reviews  with rule based approch
#get list of asins
asins=top_car_reviews["asin"].unique()
print(len(asins))

f_sufix="rule_based"
f_1_name="dataset/top_10_review_nouns_"+f_sufix+"_count.txt"
f_2_name="dataset/top_10_review_nouns_"+f_sufix+"_words.csv"

with open(f_1_name, "w+") as file_count, open(f_2_name, "w+") as file_words:
    #iterate over each product
    i=0
    for asin in asins:
        print("Starting product: "+ asin)
        #gets all reviews text for a given product as a list of strings
        review_list=get_reviews(top_car_reviews,asin)

        #get list of all nouns in all reviews
        #print(review_list)
        all_nouns=get_nouns_all_reviews(review_list,get_fuc=get_nouns_rule_based)

        #preform cleaning on noun list 
        #lemmatize
        all_nouns=lem_list(all_nouns)

        #make all words lower cases
        all_nouns = [each_string.lower() for each_string in all_nouns]

        #remove stop words from list
        all_nouns = [word for word in all_nouns if word not in stopwords.words('english')+["class="]]
        
        
        #remove words that are also in product title
        title_list=get_title_words(asin)
        all_nouns = [word for word in all_nouns if word not in title_list]
        
        
        
        #consolidate some words ie. words like 'kid', 'son', 'grandson', 'daughter', 'granddaughter', 'nephew', 'niece', 'child'
        #into single word "product_recipient"
        all_nouns=word_consolidation(all_nouns,PRODUCT_RECIPIENT_WORDS,PRODUCT_RECIPIENT)# recipient related words
        all_nouns=word_consolidation(all_nouns,PRODUCT_WORDS,PRODUCT)#product related words
        
        output_nouns(file_count,file_words,asin, all_nouns)
        
        print("Completed product: {}, {}/{}".format(asin,i,len(asins)))
        i+=1
# Out:
# 30
# Starting product: B00005LBZO
# B00005LBZO : [('product', 58), ('product_recipient', 48), ('wheel', 10), ('time', 8), ('bike', 8), ('pedal', 8), ('today', 6), ('condition', 6), ('year', 6), ('yr', 4)]
# Completed product: B00005LBZO, 0/30
# Starting product: B000GPLT68
# B000GPLT68 : [('product', 61), ('product_recipient', 36), ('race car', 12), ('wheel', 11), ('quality', 11), ('screw', 8), ('time', 8), ('gift', 6), ('plastic', 6), ('box', 5)]
# Completed product: B000GPLT68, 1/30
# Starting product: B000Q9KPB4
# B000Q9KPB4 : [('product', 37), ('display case', 21), ('quality', 12), ('model', 11), ('box', 9), ('corner', 8), ('money', 7), ('price', 7), ('time', 6), ('product_recipient', 6)]
# Completed product: B000Q9KPB4, 2/30
# Starting product: B002AKKO6S
# B002AKKO6S : [('product_recipient', 16), ('string', 12), ('sound', 12), ('product', 9), ('price', 9), ('quality', 6), ('tune', 6), ('instrument', 5), ('full size', 4), ('action', 4)]
# Completed product: B002AKKO6S, 3/30
# Starting product: B004KU83C8
# B004KU83C8 : [('product_recipient', 27), ('product', 18), ('set', 10), ('thomas', 6), ('fun', 5), ('brio products', 4), ('wheel', 4), ('box', 4), ('box cars', 4), ('track', 4)]
# Completed product: B004KU83C8, 4/30
# Starting product: B004LH01ZW
# B004LH01ZW : [('product_recipient', 23), ('product', 18), ('wheel', 7), ('battery pack', 6), ('review', 6), ('battery', 6), ('lot', 6), ('fun', 6), ('antenna', 5), ('box', 4)]
# Completed product: B004LH01ZW, 5/30
# Starting product: B006RKH1I6
# B006RKH1I6 : [('product_recipient', 16), ('arm', 9), ('robocar poli', 6), ('show', 6), ('quality', 5), ('transformer', 4), ('granddaughter', 4), ('adult', 3), ('transformation', 3), ('part', 3)]
# Completed product: B006RKH1I6, 6/30
# Starting product: B006RKBK0Q
# B006RKBK0Q : [('product_recipient', 56), ('arm', 27), ('quality', 17), ('product', 16), ('show', 15), ('robocar poli', 11), ('amazon', 10), ('leg', 10), ('time', 9), ('youtube', 6)]
# Completed product: B006RKBK0Q, 7/30
# Starting product: B006RKFHBY
# B006RKFHBY : [('product_recipient', 29), ('robocar poli', 12), ('arm', 10), ('quality', 10), ('product', 9), ('show', 6), ('korea', 5), ('old son', 5), ('transformer', 5), ('leg', 4)]
# Completed product: B006RKFHBY, 8/30
# Starting product: B00AM9SZWO
# B00AM9SZWO : [('product_recipient', 34), ('carry', 10), ('bong bong', 9), ('quality', 6), ('bong', 6), ('red bus', 5), ('bongbong', 5), ('top', 5), ('lot', 4), ('cartoon', 4)]
# Completed product: B00AM9SZWO, 9/30
# Starting product: B00APTT9SU
# B00APTT9SU : [('product_recipient', 36), ('quality', 7), ('time', 4), ('rogi', 4), ('show', 3), ('lot', 3), ('..', 3), ('wheel', 3), ('friend', 3), ('sticker', 2)]
# Completed product: B00APTT9SU, 10/30
# Starting product: B00E849LS6
# B00E849LS6 : [('product', 36), ('product_recipient', 8), ('wheel', 7), ('price', 6), ('collection', 6), ('wall', 5), ('star', 5), ('display case', 5), ('card', 5), ('shipping', 5)]
# Completed product: B00E849LS6, 11/30
# Starting product: B00J97X2YG
# B00J97X2YG : [('window', 45), ('product', 36), ('fan', 34), ('rubber', 16), ('vehicle', 15), ('air', 12), ('unit', 11), ('sun', 10), ('temperature', 9), ('difference', 9)]
# Completed product: B00J97X2YG, 12/30
# Starting product: B00JPTG45C

# %% [markdown]
# # Heuristic rule based
# Used a heuristic combining the number of times a aspect word appears along with tthe polarity

# %%
def get_pop_nouns(asin, word_list, top_n=TOP_N):
    #print 10 most commen words
    c=Counter(word_list)
    count_n=c.most_common(top_n)
    pop_words=sorted(c, key = c.get, reverse = True)[:top_n]
    return pop_words

#for all products get the top 100 nouns accross all reviews  with rule based approch
#get list of asins
asins=top_car_reviews["asin"].unique()
print(len(asins))
all_pop_nouns=[]
#iterate over each product
i=0
for asin in asins:
    print("Starting product: "+ asin)
    #gets all reviews text for a given product as a list of strings
    review_list=get_reviews(top_car_reviews,asin)

    #get list of all nouns in all reviews
    #print(review_list)
    all_nouns=get_nouns_all_reviews(review_list,get_fuc=get_nouns_rule_based)

    #preform cleaning on noun list 
    #lemmatize
    all_nouns=lem_list(all_nouns)

    #make all words lower cases
    all_nouns = [each_string.lower() for each_string in all_nouns]

    #remove stop words from list
    all_nouns = [word for word in all_nouns if word not in stopwords.words('english')+["class="]]


    #remove words that are also in product title
    title_list=get_title_words(asin)
    all_nouns = [word for word in all_nouns if word not in title_list]



    #consolidate some words ie. words like 'kid', 'son', 'grandson', 'daughter', 'granddaughter', 'nephew', 'niece', 'child'
    #into single word "product_recipient"
    all_nouns=word_consolidation(all_nouns,PRODUCT_RECIPIENT_WORDS,PRODUCT_RECIPIENT)# recipient related words
    all_nouns=word_consolidation(all_nouns,PRODUCT_WORDS,PRODUCT)#product related words

    all_pop_nouns.append(get_pop_nouns(asin, all_nouns,100))

    print("Completed product: {}, {}/{}".format(asin,i,len(asins)))
    i+=1

# %%
with open("dataset/top_100_rule_based.txt","wb") as f:
    pickle.dump(all_pop_nouns,f)

# %%
with open("dataset/top_100_rule_based.txt","rb") as f:
    all_pop_nouns=pickle.load(f)

# %%
#get the largest polarity (positive or negitve) for a aspect
def get_sent_polarity(sentence):
    sid = SentimentIntensityAnalyzer()
    ss = sid.polarity_scores(sentence)
    if ss["neg"]>= ss["pos"]:
        return ss["neg"]
    else:
        return ss["pos"]
    
get_sent_polarity("VADER is smart, handsome, and funny!")#test

# %%
def isNaN(num):
    try:
        num=float(num)
    except:
        return False 
    return math.isnan(num)
'''
takes a list of words and lemmatize then all, returns list of lemmatize words
'''
def lem_list(words):
    lemmatizer = WordNetLemmatizer()
    
    lem_list=[]
    
    for word in words:
        lem_list.append(lemmatizer.lemmatize(word))
    return lem_list

#Gets the numer of times an aspect appears in the reviews, as well as the acumilated polarity
def get_count_and_polarity(aspect, reviews):
    count=0
    arg_polarity=0
    
    #get list of consilidated words
    aspect_words=[]
    if aspect == PRODUCT:
        aspect_words=PRODUCT_WORDS
    elif aspect==PRODUCT_RECIPIENT:
        aspect_words=PRODUCT_RECIPIENT_WORDS
    
    for review in reviews:
        #print(review)
        #tokenize into sentences
        #print()
        
        if isNaN(review):
            sents=[]
            #print("NaN!")
        else:
            sents=sent_tokenize(review)
        #print(len(sents))
        
        for sent in sents:
            #tokenize into words and make lowercase
            sent=sent.lower()
            word_list=word_tokenize(sent)
        
            #lemitize words
            word_list=lem_list(word_list)
            #if sentence word list has aspect word add to cout and polarity
            if type(aspect) is str and aspect in word_list: 
                count+=1
                arg_polarity+=get_sent_polarity(sent)
            elif any(x in word_list for x in aspect_words):#handel consolidated words
                count+=1
                arg_polarity+=get_sent_polarity(sent)
            elif " " in aspect and sent.find(aspect)!=-1:#use for multi word aspect
                count+=1
                arg_polarity+=get_sent_polarity(sent)
    return count, arg_polarity


tricky_sentences = [
"Most automated sentiment analysis tools are shit.",
"VADER sentiment analysis is the shit.",
"Sentiment analysis has never been good.",
"Sentiment analysis with VADER has never been this good.",
"Warren Beatty has never been so entertaining.",
"I won't say that the movie is astounding and I wouldn't claim that \
the movie is too banal either.",
"I like to hate Michael Bay films, but I couldn't fault this one",
"I like to hate Michael Bay films, BUT I couldn't help but fault this one",
"It's one thing to watch an Uwe Boll film, but another thing entirely \
to pay for it",
"The movie was too good",
"This movie was actually neither that funny, nor super witty.",
"This movie doesn't care about cleverness, wit or any other kind of \
intelligent humor.",
"Those who find ugly meanings in beautiful things are corrupt without \
being charming.",
"There are slow and repetitive parts, BUT it has just enough spice to \
keep it interesting.",
"The script is not fantastic, but the acting is decent and the cinematography \
is EXCELLENT!",
"Roger Dodger is one of the most compelling variations on this theme.",
"Roger Dodger is one of the least compelling variations on this theme.",
"Roger Dodger is at least compelling as a variation on the theme.",
"they fall in love with the product",
"but then it breaks",
"usually around the time the 90 day warranty expires",
"the twin towers collapsed today",
"However, Mr. Carter solemnly argues, his client carried out the kidnapping \
under orders and in the ''least offensive way possible."]

get_count_and_polarity("theme",tricky_sentences)
get_count_and_polarity("roger dodger",tricky_sentences)

# %%
#Takes a list of aspects, and reviews and generates a count and polarity huristic for each aspect
def get_aspect_heuristics_list(aspect_list, reviews):
    aspect_count=[]
    aspect_polarity=[]
    
    for aspect in aspect_list:
        count, pol = get_count_and_polarity(aspect, reviews)
        aspect_count.append(count)
        aspect_polarity.append(pol)
    return aspect_count, aspect_polarity

# %%
#gets all reviews for a given product as a list of strings
def get_reviews(df, asin):
    return df[df["asin"]==asin]["reviewText"].tolist()
#get list of asins
asins=top_car_reviews["asin"].unique() 

sample_asin=random.sample(asins.tolist(), 5)
i=0
#get aspect and emotions for each asin (product)
for asin in asins:
    review_list=get_reviews(top_car_reviews,asin)
    aspect_list=all_pop_nouns[i]
    
    reviews=get_reviews(top_car_reviews,asin)
    ##Gets the numer of times an aspect appears in the reviews, as well as the acumilated polarity for each aspect
    aspect_count, aspect_polarity=get_aspect_heuristics_list(aspect_list,reviews)
    #print(asin)
    #print(len(aspect_list))
    #print(len(aspect_count))
    #print(len(aspect_polarity))
    
    #get average polarity per aspect by dividing by count
    aspect_count=np.array(aspect_count)
    aspect_polarity=np.array(aspect_polarity)
    
    avg_aspect_pol = np.divide(aspect_polarity, aspect_count, out=np.zeros_like(aspect_polarity), where=aspect_count!=0)
    #print(avg_aspect_pol)
    
    #show figure 
    fig, ax = plt.subplots()
    ax.scatter(aspect_count, avg_aspect_pol)

    for j, txt in enumerate(aspect_list):
        ax.annotate(txt, (aspect_count[j], avg_aspect_pol[j]))
    break

# %%
#sort aspect and output based on heuristic of each aspect
def output_heuristic_aspects(f,asin, aspect_list,aspect_value, top_n=TOP_N):
    
    #sort aspect based on heuristic
    zipped_lists = zip(aspect_value, aspect_list)
    sorted_pairs = sorted(zipped_lists)

    tuples = zip(*sorted_pairs)
    aspect_value, aspect_list = [ list(tuple) for tuple in  tuples]
    aspect_list.reverse()
    aspect_value.reverse()
    
    
    #print(aspect_list)
    #print(aspect_value)
    
    i=0
    #print top 10 words
    #get top n where heuristic_importance is greater then 0.1
    print("{},".format(asin), file = f, end="")
    for word in aspect_list:
        if word==aspect_list[-1]:
            print("{}".format(word), file = f, end="")
        elif aspect_value[i+1]<0.1 or i+1==top_n:#if value is less than 0.1 stop printing
            print("{}".format(word), file = f, end="")
            break
        else:
            print("{},".format(word), file = f, end="")
        i+=1
    print("",file = f)
a=['a','b','c','d','e']
b=[8,1,6,3,7]
with open("dataset/test_h_out.csv","w+") as f:
    output_heuristic_aspects(f,"000",a,b)

# %%
#gets all reviews for a given product as a list of strings
def get_reviews(df, asin):
    return df[df["asin"]==asin]["reviewText"].tolist()
#get list of asins
asins=top_car_reviews["asin"].unique() 

i=0

with open("dataset/top_10_review_nouns_rule_heuristic_words.csv","w+") as f:
    #get aspect and emotions for each asin (product)
    for asin in asins:
        print("Started product "+asin)
        review_list=get_reviews(top_car_reviews,asin)
        aspect_list=all_pop_nouns[i]

        reviews=get_reviews(top_car_reviews,asin)
        ##Gets the numer of times an aspect appears in the reviews, as well as the acumilated polarity for each aspect
        aspect_count, aspect_polarity=get_aspect_heuristics_list(aspect_list,reviews)
        #print(asin)
        #print(len(aspect_list))
        #print(len(aspect_count))
        #print(len(aspect_polarity))

        #get average polarity per aspect by dividing by count
        aspect_count=np.array(aspect_count)
        aspect_polarity=np.array(aspect_polarity)

        avg_aspect_pol = np.divide(aspect_polarity, aspect_count, out=np.zeros_like(aspect_polarity), where=aspect_count!=0)
        #print(avg_aspect_pol)

        #output huristicly sorted values
        #=(polarity*count^2)/10
        heuristic_importance=(avg_aspect_pol*aspect_count*aspect_count)/10

        #sort aspect and output based on heuristic
        #get top n where heuristic_importance is greater then 0
        output_heuristic_aspects(f,asin,aspect_list,heuristic_importance)
        
        print("Cmpleted product {}... {}/30".format(asin,i+1))
        
        i+=1
